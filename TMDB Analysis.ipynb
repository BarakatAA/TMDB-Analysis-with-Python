# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("tmdb.xlsx")

# %%
# checking no of columns and basic info about the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10869 entries, 0 to 10868
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10867 non-null  float64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  float64
#  4   revenue               10866 non-null  float64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  float64
#  13  Main_genre            10843 non-null  object
# ...

# %%
df.head()
# Out:
#          id    imdb_id  popularity       budget       revenue  \
# 0  135397.0  tt0369610   32.985763  150000000.0  1.513529e+09
# 1   76341.0  tt1392190   28.419936  150000000.0  3.784364e+08
# 2  262500.0  tt2908446   13.112507  110000000.0  2.952382e+08
# 3  140607.0  tt2488496   11.173104  200000000.0  2.068178e+09
# 4  168259.0  tt2820852    9.335014  190000000.0  1.506249e+09
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
# ...

# %%
df.size
# Out:
# 271725

# %%
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10867.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66058.192878      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92128.009393      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10594.500000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20662.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75608.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj  \
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
df.isna()
# Out:
#           id  imdb_id  popularity  budget  revenue  original_title   cast  \
# 0      False    False       False   False    False           False  False
# 1      False    False       False   False    False           False  False
# 2      False    False       False   False    False           False  False
# 3      False    False       False   False    False           False  False
# 4      False    False       False   False    False           False  False
# ...      ...      ...         ...     ...      ...             ...    ...
# 10864  False    False       False   False    False           False  False
# 10865  False    False       False   False    False           False  False
# 10866   True     True        True    True     True            True   True
# 10867   True     True        True    True     True            True   True
# 10868  False     True        True    True     True            True   True
#
#        homepage  director  tagline  ...  production_companies  release_date  \
# ...

# %%
df.shape
# Out:
# (10869, 25)

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10864    False
# 10865    False
# 10866    False
# 10867    False
# 10868    False
# Length: 10869, dtype: bool

# %%
df.isnull().sum() # to get total number of null values n each column
# Out:
# id                          2
# imdb_id                    13
# popularity                  3
# budget                      3
# revenue                     3
# original_title              3
# cast                       79
# homepage                 7933
# director                   47
# tagline                  2827
# keywords                 1496
# overview                    7
# runtime                     3
# Main_genre                 26
# genres                     26
# production_companies     1032
# release_date                3
# vote_count                  3
# vote_average                3
# release_year                3
# budget_adj                  3
# revenue_adj                 3
# Unnamed: 22             10869
# Unnamed: 23             10869
# Unnamed: 24             10868
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df[df.homepage.isnull()]
# Out:
#              id    imdb_id  popularity      budget      revenue  \
# 18     150689.0  tt1661199    5.556818  95000000.0  542351353.0
# 21     307081.0  tt1798684    5.337064  30000000.0   91709827.0
# 26     214756.0  tt2637276    4.564549  68000000.0  215863606.0
# 32     254470.0  tt2848292    3.877764  29000000.0  287506194.0
# 33     296098.0  tt3682448    3.648210  40000000.0  162610473.0
# ...         ...        ...         ...         ...          ...
# 10864   21449.0  tt0061177    0.064317         0.0          0.0
# 10865   22293.0  tt0060666    0.035919     19000.0          0.0
# 10866       NaN        NaN         NaN         NaN          NaN
# 10867       NaN        NaN         NaN         NaN          NaN
# 10868    1030.0        NaN         NaN         NaN          NaN
#
#                  original_title  \
# 18                   Cinderella
# 21                     Southpaw
# 26                        Ted 2
# 32              Pitch Perfect 2
# ...

# %%
df.drop(["homepage", "tagline"], axis = 1) #there are two axis 1 and zero
# the row axis is 0 and column axis is 1
# Out:
#              id    imdb_id  popularity       budget       revenue  \
# 0      135397.0  tt0369610   32.985763  150000000.0  1.513529e+09
# 1       76341.0  tt1392190   28.419936  150000000.0  3.784364e+08
# 2      262500.0  tt2908446   13.112507  110000000.0  2.952382e+08
# 3      140607.0  tt2488496   11.173104  200000000.0  2.068178e+09
# 4      168259.0  tt2820852    9.335014  190000000.0  1.506249e+09
# ...         ...        ...         ...          ...           ...
# 10864   21449.0  tt0061177    0.064317          0.0  0.000000e+00
# 10865   22293.0  tt0060666    0.035919      19000.0  0.000000e+00
# 10866       NaN        NaN         NaN          NaN           NaN
# 10867       NaN        NaN         NaN          NaN           NaN
# 10868    1030.0        NaN         NaN          NaN           NaN
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# ...

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'Main_genre', 'genres', 'production_companies',
#        'release_date', 'vote_count', 'vote_average', 'release_year',
#        'budget_adj', 'revenue_adj', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10869 entries, 0 to 10868
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10867 non-null  float64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  float64
#  4   revenue               10866 non-null  float64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  float64
#  13  Main_genre            10843 non-null  object
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of              id    imdb_id  popularity       budget       revenue  \
# 0      135397.0  tt0369610   32.985763  150000000.0  1.513529e+09
# 1       76341.0  tt1392190   28.419936  150000000.0  3.784364e+08
# 2      262500.0  tt2908446   13.112507  110000000.0  2.952382e+08
# 3      140607.0  tt2488496   11.173104  200000000.0  2.068178e+09
# 4      168259.0  tt2820852    9.335014  190000000.0  1.506249e+09
# ...         ...        ...         ...          ...           ...
# 10864   21449.0  tt0061177    0.064317          0.0  0.000000e+00
# 10865   22293.0  tt0060666    0.035919      19000.0  0.000000e+00
# 10866       NaN        NaN         NaN          NaN           NaN
# 10867       NaN        NaN         NaN          NaN           NaN
# 10868    1030.0        NaN         NaN          NaN           NaN
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# ...

# %%
df.sum()
# Out:
# C:\Users\akinj\AppData\Local\Temp\ipykernel_2000\1703867807.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.sum()
# id              7.178544e+08
# popularity      7.024227e+03
# budget          1.589229e+11
# revenue         4.327202e+11
# runtime         1.109102e+06
# vote_count      2.362157e+06
# vote_average    6.492350e+04
# release_year    2.174637e+07
# budget_adj      1.907096e+11
# revenue_adj     5.581252e+11
# Unnamed: 22     0.000000e+00
# Unnamed: 23     0.000000e+00
# Unnamed: 24     1.000000e+00
# dtype: float64

# %%
df.drop([10866, 10867, 10868], axis = 0, inplace = True)

# %%
df.drop(["Unnamed: 22", "Unnamed: 23"], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  float64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  float64
#  4   revenue               10866 non-null  float64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  float64
#  13  Main_genre            10843 non-null  object
# ...

# %%
df.drop(["Unnamed: 24"], axis = 1, inplace = True )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18064\3077036124.py in <module>
# ----> 1 df.drop(["Unnamed: 24"], axis = 1, inplace = True )
#
# NameError: name 'df' is not defined

# %%
def plot_cat(var, 1 = 10, b = 5):
    plt.figure(figsize = (1, b))
    sns.countplot(df[var]), order = df[var].value_counts()
    plt.xticks(rotation = 75)
    
    plot_cat('genres')
# Out:
#   File "C:\Users\akinj\AppData\Local\Temp\ipykernel_2000\1079475496.py", line 1
#     def plot_cat(var, 1 = 10, b = 5):
#                       ^
# SyntaxError: invalid syntax

# %%
df['profit'] = df.revenue_adj - df.budget_adj

# %%
df.head()
# Out:
#    popularity       budget       revenue                original_title  \
# 0   32.985763  150000000.0  1.513529e+09                Jurassic World
# 1   28.419936  150000000.0  3.784364e+08            Mad Max: Fury Road
# 2   13.112507  110000000.0  2.952382e+08                     Insurgent
# 3   11.173104  200000000.0  2.068178e+09  Star Wars: The Force Awakens
# 4    9.335014  190000000.0  1.506249e+09                     Furious 7
#
#    runtime Main_genre         release_date  vote_count  vote_average  \
# 0    124.0     Action  2015-09-06 00:00:00      5562.0           6.5
# 1    120.0     Action              5/13/15      6185.0           7.1
# 2    119.0  Adventure              3/18/15      2480.0           6.3
# 3    136.0     Action             12/15/15      5292.0           7.5
# 4    137.0     Action  2015-01-04 00:00:00      2947.0           7.3
#
#   release_year    budget_adj   revenue_adj     main_director  \
# ...

# %%
df['main_genre'] = df.genres.str.split(pat ='|', expand = True)[0]

# %%
df.head()

# %%
df['main_director'] = df.director.str.split(pat ='|', expand = True)[0]
df['main_cast'] = df.cast.str.split(pat = '|', expand = True)[0]
df['main_production_company'] = df.production_companies.str.split(pat ='|', expand = True)[0]

# %%
df.head()
# Out:
#    popularity       budget       revenue                original_title  \
# 0   32.985763  150000000.0  1.513529e+09                Jurassic World
# 1   28.419936  150000000.0  3.784364e+08            Mad Max: Fury Road
# 2   13.112507  110000000.0  2.952382e+08                     Insurgent
# 3   11.173104  200000000.0  2.068178e+09  Star Wars: The Force Awakens
# 4    9.335014  190000000.0  1.506249e+09                     Furious 7
#
#    runtime Main_genre         release_date  vote_count  vote_average  \
# 0    124.0     Action  2015-09-06 00:00:00      5562.0           6.5
# 1    120.0     Action              5/13/15      6185.0           7.1
# 2    119.0  Adventure              3/18/15      2480.0           6.3
# 3    136.0     Action             12/15/15      5292.0           7.5
# 4    137.0     Action  2015-01-04 00:00:00      2947.0           7.3
#
#   release_year    budget_adj   revenue_adj     main_director  \
# ...

# %%
# dropping all columns that are no longer needed for analysis with df.drop
df.columns
# Out:
# Index(['popularity', 'budget', 'revenue', 'original_title', 'runtime',
#        'Main_genre', 'release_date', 'vote_count', 'vote_average',
#        'release_year', 'budget_adj', 'revenue_adj', 'main_director',
#        'main_cast', 'main_production_company'],
#       dtype='object')

# %%
df.drop(['production_companies', 'id', 'imdb_id', 'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview'], axis = 1, inplace = True)

# %%
df.isnull().sum()
# Out:
# popularity                    0
# budget                        0
# revenue                       0
# original_title                0
# runtime                       0
# Main_genre                   23
# release_date                  0
# vote_count                    0
# vote_average                  0
# release_year                  0
# budget_adj                    0
# revenue_adj                   0
# main_director                44
# main_cast                    76
# main_production_company    1030
# dtype: int64

# %%
df.drop(['genres'], axis = 1, inplace = True)

# %%
df.isnull().sum()
# Out:
# popularity                    0
# budget                        0
# revenue                       0
# original_title                0
# runtime                       0
# Main_genre                   23
# release_date                  0
# vote_count                    0
# vote_average                  0
# release_year                  0
# budget_adj                    0
# revenue_adj                   0
# main_director                44
# main_cast                    76
# main_production_company    1030
# dtype: int64

# %%
df[df.main_director.isna()]
# Out:
#        popularity     budget     revenue  \
# 532      0.126594        0.0         0.0
# 548      0.108072        0.0         0.0
# 556      0.100910        0.0         0.0
# 1032     0.291253        0.0         0.0
# 1054     0.269468        0.0         0.0
# 1203     0.119891   150000.0         0.0
# 1241     0.135376        0.0         0.0
# 1288     0.038364        0.0         0.0
# 1852     0.256703        0.0         0.0
# 1872     0.091395  3250000.0         0.0
# 1895     0.056777        0.0         0.0
# 2221     0.281852        0.0         0.0
# 2286     0.207234        0.0         0.0
# 2290     0.203502        0.0         0.0
# 2315     0.171615        0.0         0.0
# 2318     0.170408        0.0         0.0
# 2376     0.068411        0.0         0.0
# 2397     0.033048        0.0         0.0
# 2401     0.067753        0.0         0.0
# 2403     0.067620        0.0         0.0
# 3171     0.019819        0.0         0.0
# 3224     0.224721        0.0         0.0
# ...

# %%
df[df.main_cast.isna()]
# Out:
#        popularity  budget  revenue  \
# 371      0.422901     0.0      0.0
# 441      0.220751     0.0      0.0
# 465      0.201696     0.0      0.0
# 536      0.122543     0.0      0.0
# 538      0.114264     0.0      0.0
# ...           ...     ...      ...
# 9677     0.253376     0.0      0.0
# 9755     0.046272     0.0      0.0
# 10434    0.146906   200.0      0.0
# 10550    0.306425     0.0      0.0
# 10754    0.002757     0.0      0.0
#
#                                     original_title  runtime   Main_genre  \
# 371                            Sanjay's Super Team      7.0    Animation
# 441    Winter on Fire: Ukraine's Fight for Freedom     98.0  Documentary
# 465                                    Bitter Lake    135.0  Documentary
# 536                                 A Faster Horse     90.0  Documentary
# 538                           The Mask You Live In     88.0  Documentary
# ...                                            ...      ...          ...
# ...

# %%
df[df.Main_genre.isna()]
# Out:
#        popularity  budget  revenue  \
# 424      0.244648     0.0      0.0
# 620      0.129696     0.0      0.0
# 997      0.330431     0.0      0.0
# 1712     0.302095     0.0      0.0
# 1897     0.020701     0.0      0.0
# 2370     0.081892     0.0      0.0
# 2376     0.068411     0.0      0.0
# 2853     0.130018     0.0      0.0
# 3279     0.145331     0.0      0.0
# 4547     0.520520     0.0      0.0
# 4732     0.235911     0.0      0.0
# 4797     0.167501     0.0      0.0
# 4890     0.083202     0.0      0.0
# 5830     0.248944     0.0      0.0
# 5934     0.067433     0.0      0.0
# 6043     0.039080     0.0      0.0
# 6530     0.092724     0.0      0.0
# 8234     0.028874     0.0      0.0
# 8614     0.273934     0.0      0.0
# 8878     0.038045     0.0      0.0
# 9307     0.094652     0.0      0.0
# 9799     0.175008     0.0      0.0
# 10659    0.344172  5000.0      0.0
#
#                                           original_title  runtime Main_genre  \
# ...

# %%
df.dropna(['Main_genre'], inplace = True)

# %%
df['release_year'] = df['release_year'].astype(int).astype(str)

# %%
df.dtypes
# Out:
# popularity                 float64
# budget                     float64
# revenue                    float64
# original_title              object
# runtime                    float64
# Main_genre                  object
# release_date                object
# vote_count                 float64
# vote_average               float64
# release_year                object
# budget_adj                 float64
# revenue_adj                float64
# main_director               object
# main_cast                   object
# main_production_company     object
# dtype: object

# %%
df.head()
# Out:
#    popularity       budget       revenue                original_title  \
# 0   32.985763  150000000.0  1.513529e+09                Jurassic World
# 1   28.419936  150000000.0  3.784364e+08            Mad Max: Fury Road
# 2   13.112507  110000000.0  2.952382e+08                     Insurgent
# 3   11.173104  200000000.0  2.068178e+09  Star Wars: The Force Awakens
# 4    9.335014  190000000.0  1.506249e+09                     Furious 7
#
#    runtime Main_genre         release_date  vote_count  vote_average  \
# 0    124.0     Action  2015-09-06 00:00:00      5562.0           6.5
# 1    120.0     Action              5/13/15      6185.0           7.1
# 2    119.0  Adventure              3/18/15      2480.0           6.3
# 3    136.0     Action             12/15/15      5292.0           7.5
# 4    137.0     Action  2015-01-04 00:00:00      2947.0           7.3
#
#   release_year    budget_adj   revenue_adj     main_director  \
# ...

# %% [markdown]
# ### Exploratory data analysis
#
#
# Question 1: Will the popularity rating of a movie of a movie affect its revenue

# %%
sns.regplot(x = 'popularity', y = 'revenue_adj', data = df)
plt.title ('Popularity level vs Revenue Generation')

# The plot shows a positive correlation and that a high popularity level leads to more revenue generation as the more popular a movie, the higher revenue it generates
# Out:
# Text(0.5, 1.0, 'Popularity level vs Revenue Generation')

# %% [markdown]
# Question 2
#
# Can the budget allocated to a movie affect its revenue generation?

# %%
sns.regplot(x = 'revenue_adj', y = 'budget_adj', data = df)
plt.title ('Budget Allocation vs Revenue Generation')
# Shows a positive correlation too and that movies with higher budgets gave more revenue
# Out:
# Text(0.5, 1.0, 'Budget Allocation vs Revenue Generation')

# %% [markdown]
# Question 3
#
#
# What movies are the most popular?

# %%
most_popular_movies = df.sort_values(by = 'popularity', ascending = False).head(10)

sns.barplot(x = 'original_title', y = 'popularity', data = most_popular_movies)
plt.xticks(rotation = 90)
plt.title = 'Most Popular movies'

plt.show()

# %% [markdown]
# The movie with the most popularity is Jurassic World followed by Mad Max Fury and Interstellar

# %% [markdown]
# ### Question 4
#
# Which genre is the most popular?

# %%
most_popular_genre = df.sort_values(by = 'popularity', ascending = False).head(10)

sns.barplot(x = 'Main_genre', y = 'popularity', data = most_popular_genre)
plt.xticks(rotation = 90)
plt.title = 'Most Popular movies'

plt.show()

# %% [markdown]
# The Action genre is the most popular followed by Adventure and Science Fiction

# %% [markdown]
# ### Question 5
#
# What genre brought in the most profit?

# %%
""""genres_vs_profits = df.groupby('Main_genre')('profit').sort_values(ascending = False).head(10)

y = most_popular_movies['Main_genre']
x = most_popular_movies['profit']
sns.barplot(x, y)
plt.xticks(rotation = 90)

plt.title('most_popular_movie_genres')

plt.show()"""

# %%
genres_vs_profit = df.sort_values(by = 'profit', ascending = False).head(10)

sns.barplot(x = 'Main_genre', y = 'profit', data = genres_vs_profit)
plt.xticks(rotation = 90)
plt.title = 'Genres vs Profit '

plt.show()

# %%
# creating a function to calculate count so as not to repeatedly write code

def plot_cat(var, l=12, b=5):
    plt.figure(figsize = (l, b))
    sns.countplot(df[var], order = df[var].value_counts().index)
    plt.xticks(rotation = 90)

# %% [markdown]
# ### Question 6
#
# Which year had the most movie releases?

# %%
plot_cat('release_year')
# Out:
# C:\Users\akinj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# This shows that 2014 had the most movie releases of around 700 movies followed by 2013 and 2015. 1969 had the least movie releas

# %% [markdown]
# ### Question 7
#
# Which genre had the most released movies?

# %%
plot_cat('Main_genre')
# Out:
# C:\Users\akinj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# This shows that drama had the most released movies across the years with close to 2500 movies
